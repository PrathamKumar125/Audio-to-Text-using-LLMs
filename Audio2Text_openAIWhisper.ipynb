# %% [markdown]
# <a href="https://colab.research.google.com/github/PrathamKumar125/Audio-to-Text-using-LLMs/blob/master/Audio2Text_openAIWhisper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install git+https://github.com/openai/whisper.git -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 19.6 MB/s eta 0:00:00
# ...

# %%
import whisper

model = whisper.load_model("base")
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:04<00:00, 30.1MiB/s]

# %%
model.device
# Out:
# device(type='cuda', index=0)

# %%
# !mkdir /content/dataset

# %%
# !cp -r /content/drive/MyDrive/NLP/dataset_audio/* /content/dataset/

# %%
from IPython.display import Audio
Audio("/content/dataset/-7020799700.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# load audio and pad/trim it to fit 30 seconds
audio = whisper.load_audio("/content/dataset/-7020799700.mp3")
audio = whisper.pad_or_trim(audio)

# make log-Mel spectrogram and move to the same device as the model
mel = whisper.log_mel_spectrogram(audio).to(model.device)

# detect the spoken language
_, probs = model.detect_language(mel)
print(f"Detected language: {max(probs, key=probs.get)}")

# decode the audio
options = whisper.DecodingOptions()
result = whisper.decode(model, mel, options)

# print the recognized text
print(result.text)
# Out:
# Detected language: hi
# पाचे वो राचे वो नमशकार मैं पर साशनी सुदार वोग काचे वोगा वोगा वोगा वोगा वोगा वोगा वोगा वोगा वोगा वोगा वोगा वोगा वोगा वोगा वोगा वोगा वोगा वोगा वोगा वोगा वोगा वोगा वोगा वोगा वोगा वोगा वोगा वोगा

# %%
def transcribe(audio):

    #time.sleep(3)
    # load audio and pad/trim it to fit 30 seconds
    audio = whisper.load_audio(audio)
    audio = whisper.pad_or_trim(audio)

    # make log-Mel spectrogram and move to the same device as the model
    mel = whisper.log_mel_spectrogram(audio).to(model.device)

    # detect the spoken language
    _, probs = model.detect_language(mel)
    print(f"Detected language: {max(probs, key=probs.get)}")

    # decode the audio
    options = whisper.DecodingOptions()
    result = whisper.decode(model, mel, options)
    return result.text

# %%
# !pip install gradio==3.50
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 37.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 14.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 36.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 16.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 20.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 13.0 MB/s eta 0:00:00
# ...

# %%
import gradio as gr
import time

# %%
gr.Interface(
    title="OpenAI-Whisper Audio to Text Web UI",
    fn=transcribe,
    inputs=[gr.components.Audio(type="filepath")],
    outputs=["textbox"],
    live=True
).launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://35592e05a34a906ca3.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://35592e05a34a906ca3.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# %cd /content/
# Out:
# /content

# %%
# !gradio deploy
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/gradio", line 8, in <module>
#     sys.exit(cli())
#   File "/usr/local/lib/python3.10/dist-packages/gradio/cli.py", line 15, in cli
#     gradio.deploy_space.deploy()
#   File "/usr/local/lib/python3.10/dist-packages/gradio/deploy_space.py", line 167, in deploy
#     hf_api.upload_folder(
#   File "/usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py", line 118, in _inner_fn
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/huggingface_hub/hf_api.py", line 1208, in _inner
#     return fn(self, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/huggingface_hub/hf_api.py", line 4565, in upload_folder
#     add_operations = _prepare_upload_folder_additions(
#   File "/usr/local/lib/python3.10/dist-packages/huggingface_hub/hf_api.py", line 8265, in _prepare_upload_folder_additions
#     return [
# ...
